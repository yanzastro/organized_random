# %% [markdown]
# !pip install minisom

# %%
import fitsio
from astropy.io import fits
import numpy as np
from minisom import MiniSom

# %% [markdown]
# kids_goldsample = fits.open('/net/home/fohlen13/yanza21/DATA/KiDS_data/KiDS_DR4.1_ugriZYJHKs_SOM_gold_WL_cat.fits')
# data_table = kids_goldsample[1].data
# rows_numbers_to_keep = np.random.choice(len(data_table), 1000000, replace=False)
# fits.writeto('/net/home/fohlen13/yanza21/DATA/KiDS_data/KiDS_gold_smallsample.fits', kids_goldsample[1].data[rows_numbers_to_keep], overwrite=True)

# %%
kids_goldsample = fitsio.FITS('/net/home/fohlen13/yanza21/DATA/KiDS_data/KiDS_gold_smallsample.fits')

# %%
class cat2som:
    def __init__(self, training_data, colnames, **kwargs):
        self.training_data = training_data
        self.colnames = colnames
        self.som_dim = int((5*(train_data.shape[0])**0.5)**0.5)
        self.som = MiniSom(som_dim, som_dim, training_.shape[1], 
                           **kwargs) # initialization of 6x6 SOM
        #som.random_weights_init(train_data)
        self.som.pca_weights_init(train_data)
        
    def train_som(self, n_iter):
        self.som.train(self.training_data, n_iter)
        
    def get_activation_map(self, testing_data):
        return self.som.activation_response(testing_data) 
        
    def som_ind_to_1d(self, xi, yi):
        return xi * self.som_dim + yi
        
    def get_winner_ind(self, testing_data):
        winner_x = np.zeros(testing_data.shape[0])
        winner_y = np.zeros(testing_data.shape[0])
        winner_1dind = np.zeros(testing_data.shape[0])

        for i in tqdm(range(len(testing_data))):
            data = testing_data[i]
            x,y = self.som.winner(data)
            feature_map[x,y] += data[0]
            winner_x[i] = x
            winner_y[i] = y
            winner_1dind[i] = self.som_ind_to_1d(x, y)
            
        return winner_x, winner_y, winner_1dind
    
    def get_feature_map(self, testing_data, col_ind):
        x, y, winner_1dind = self.get_winner_ind(testing_data)
        for i in range(len(testing_data)):
            data = testing_data[i]
            feature_map[x[i],y[i]] += data[col_ind]
        
        activation_map = self.get_activation_map(testing_data)
        feature_map_dict = {'colname': self.colnames[col_ind],
                           'feature_map': feature_map/activation_map}
        return feature_map_dict
# Out:
#   File "<ipython-input-17-4aaca5f346d9>", line 35
#     def get_feature_map(self, testing_data)
#                                            ^
# SyntaxError: invalid syntax

# %%
import healpy as hp
'''
train_data = np.array(kids_goldsample[1]['MU_THRESHOLD',
                                         'FWHM_WORLD', 
                                         'PSF_e1',
                                         'PSF_e2', 
                                         'MAG_LIM_u', 
                                         'MAG_LIM_g',
                                         'MAG_LIM_r',
                                         'MAG_LIM_i',
                                         'MAG_LIM_Z',
                                         'MAG_LIM_Y',
                                         'MAG_LIM_J',
                                         'MAG_LIM_H',
                                         'MAG_LIM_Ks', 
                                         'EXTINCTION_r'][:].tolist())'''

columns_selected = ['MU_THRESHOLD', 'PSF_Q12', 'PSF_e1','PSF_e2', 'MAG_LIM_r', 'EXTINCTION_r']
columns_syst = ['MU_THRESHOLD', 'PSF_Q12', 'PSF_ell', 'MAG_LIM_r', 'EXTINCTION_r']
column_edges = np.array([[20,30], [-2, 2], [-1,1],  [20, 30], [-1,1]])

train_data = []

for key in columns_selected:
    train_data.append(kids_goldsample[1][key][:1000000].tolist())
train_data = np.array(train_data).T

radec = np.array(kids_goldsample[1]['ALPHA_J2000', 'DELTA_J2000'][:1000000].tolist())

e = (train_data.T[2]**2 + train_data.T[3]**2) ** 0.5
q = (1-e)/(e+1)
train_data = np.vstack([train_data.T[0], train_data.T[1], 1-q, train_data.T[4], train_data.T[5]]).T

outliers = np.zeros(train_data.shape[0])
for i in range(train_data.shape[1]):
    l = train_data.T[i]
        
    dist_to_mean = l - l.mean()
    std = np.std(l[~np.isnan(l)])
    
    outliers += np.logical_or(l<column_edges[i][0], l>column_edges[i][1])    
    outliers += np.logical_or(l==+np.inf, l==-np.inf)
    outliers += np.isnan(l)

radec_edges = np.array([[0,360], [-90, 90]])
for i in range(2):
    radec_i = radec.T[i]
    outliers += np.isnan(radec_i)
    outliers += np.logical_or(radec_edges<column_edges[i][0], radec_edges>column_edges[i][1])    
    outliers += np.logical_or(radec_edges==+np.inf, radec_edges==-np.inf)
    
invalid_ind = np.where(outliers>0)[0]

radec = np.delete(radec, invalid_ind, axis=0)

train_data = np.delete(train_data, invalid_ind, axis=0)
train_data_raw = train_data.copy()

train_data = (train_data - np.mean(train_data, axis=0)) / np.std(train_data, axis=0)
# Out:
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
def som_ind_to_1d(xi, yi, som_dim):
    return xi * som_dim + yi

# %% [markdown]
# train_data = np.array(kids_goldsample[1]['MAG_GAAP_u',
#                                          'MAG_GAAP_g',
#                                          'MAG_GAAP_r',
#                                          'MAG_GAAP_i',
#                                          'MAG_GAAP_Z',
#                                          'MAG_GAAP_Y',
#                                          'MAG_GAAP_J',
#                                          'MAG_GAAP_H',
#                                          'MAG_GAAP_Ks',][:].tolist())
#
# invalid_ind = np.where(np.logical_or(train_data<1, train_data==99, np.isnan(train_data)))[0]
# train_data = np.delete(train_data, invalid_ind, axis=0)
# train_data = (train_data.T[1:] - train_data.T[:-1]).T
# #train_data = train_data[np.where(~np.isnan(np.sum(train_data, axis=1)))[0]]
# train_data = (train_data - np.mean(train_data, axis=0)) / np.std(train_data, axis=0)

# %%
som_dim = int((5*(train_data.shape[0])**0.5)**0.5)
som = MiniSom(som_dim, som_dim, train_data.shape[1], sigma=1, learning_rate=1, 
              neighborhood_function='gaussian', topology='hexagonal', random_seed=0) # initialization of 6x6 SOM
#som.random_weights_init(train_data)
som.pca_weights_init(train_data)
som.train(train_data, 500000)
# Out:
# 100%|██████████| 500000/500000 [04:19<00:00, 1927.59it/s]

# %% [markdown]
# som.train(train_data, 100000, random_order=True, verbose=True)

# %%
from matplotlib.patches import RegularPolygon, Ellipse
from matplotlib import cm, colorbar

testing_data = train_data
umatrix = som.activation_response(testing_data)

# %% [markdown]
# som.train_batch(train_data, 1000)

# %%
from tqdm import tqdm
feature_map = np.zeros((som_dim, som_dim))
winner_x = np.zeros(testing_data.shape[0])
winner_y = np.zeros(testing_data.shape[0])
winner_1dind = np.zeros(testing_data.shape[0])

for i in tqdm(range(len(testing_data))):
    data = testing_data[i]
    x,y = som.winner(data)
    feature_map[x,y] += data[0]
    winner_x[i] = x
    winner_y[i] = y
    winner_1dind[i] = som_ind_to_1d(x, y, som_dim)
# Out:
# 100%|██████████| 956153/956153 [02:10<00:00, 7348.92it/s]

# %%
def plot_som(ax, som_heatmap, topology='rectangular', colormap=cm.viridis):
    if topology == 'rectangular':
        ax.matshow(som_heatmap.T, cmap=colormap)
    else:
        cscale = som_heatmap / som_heatmap[~np.isnan(som_heatmap)].max()
        som_dim = cscale.shape[0]
        yy, xx= np.meshgrid(np.arange(som_dim), np.arange(som_dim))
        shift = np.zeros(som_dim)
        shift[::2]=-0.5
        xx = xx + shift
        for i in range(cscale.shape[0]):
            for j in range(cscale.shape[1]):
                wy = yy[(i, j)] * np.sqrt(3) / 2
                if (cscale[i,j] == 0 or (np.isnan(cscale[i,j]))):
                    color = 'k'
                else:
                    color = colormap(cscale[i,j])
            
                hex = RegularPolygon((xx[(i, j)], wy), 
                                 numVertices=6, 
                                 radius= 1 / np.sqrt(3),
                                 facecolor=color, 
                                 edgecolor=color,
                                 #alpha=.4, 
                                 lw=0,)
                ax.add_patch(hex)

        scmap = plt.scatter([0,0],[0,0], s=0, c=[som_heatmap[~np.isnan(som_heatmap)].min(),
                                                 som_heatmap[~np.isnan(som_heatmap)].max()], 
                            cmap=colormap)
        ax.set_xlim(-1,som_dim-.5)
        ax.set_ylim(-0.5,som_dim * np.sqrt(3) / 2)
        plt.colorbar(scmap)

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(10,10))
ax = f.add_subplot(111)
ax.set_aspect('equal')
plot_som(ax, feature_map/umatrix, topology='hex', colormap=cm.coolwarm)
# Out:
# /net/home/fohlen13/yanza21/anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(10,10))
ax = f.add_subplot(111)

ax.set_aspect('equal')
plot_som(ax, umatrix, topology='hex', colormap=cm.coolwarm)

# %%
Ns = 256
radec[radec.T.argmax()] = [0,0]
radec[np.logical_or(radec.T[1]>90,radec.T[1]<-90)] = [0,0]
radec = np.round(radec,3)


hp_ind = hp.ang2pix(Ns, radec.T[0], radec.T[1], lonlat=True)

hp_ind_unique, n_p = np.unique(hp_ind, return_counts=True)  # this line gives the unique healpix pixel indices that contains at least one galaxy, as well as the number of galaxies in each pixel 
A_p = hp.nside2pixarea(Ns) * hp_ind_unique.size  # the total area of the footprint

som_1dind_unique = np.unique(winner_1dind)  # the unique SOM pixel indices (in 1D)
delta_i_sum = 0
weight_map = np.zeros(hp.nside2npix(Ns))
for som_ind in som_1dind_unique:
    source_ind = np.where(winner_1dind==som_ind)[0]  # pick out the catalog indices of sources that are in the som_ind'th SOM pixel
    n_i = source_ind.size  # and the number of sources in that SOM pixel
    hp_ind_ = hp_ind[source_ind]  # and the Healpix pixel indices
    hp_ind_insomi_unique, n_p_i = np.unique(hp_ind_, return_counts=True)  # n_p_i is the number of sources that are in the i (som_ind here)-th SOM cell in each Healpix pixel
    A_p_i = n_p_i/n_p[np.intersect1d(hp_ind_unique, hp_ind_insomi_unique, return_indices=True)[1]] * A_p  # the effective pixel area for the i-th SOM cell
    A_i = np.sum(A_p_i)  # the total effective area for the i-th SOM cell
    delta_i = n_i / A_i  # effective number density 
    delta_i_sum += delta_i
    weight_map[hp_ind_insomi_unique] += delta_i * n_p_i  # weight of each Healpix pixel
    
weight_map/=np.mean(delta_i_sum)

# %%
weight_map[weight_map==0] = hp.UNSEEN

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

hp.cartview(weight_map, lonra=[125, 240], latra=[-5,4], xsize=8000, title='KiDS-North')

# %%
hp.cartview(weight_map, lonra=[-31, 55], latra=[-37,-26], title='KiDS-South')

# %%
for sys_ind in range(train_data.shape[1]):
    #sys_ind = 1
    hp.cartview(np.ones_like(weight_map)*hp.UNSEEN, lonra=[-31, 55], latra=[-37,-26], title='KiDS-South, '+columns_syst[sys_ind], flip='geo', cbar=None)
    hp.projscatter(radec.T[0], radec.T[1], lonlat=True, c=testing_data.T[sys_ind], cmap='coolwarm', s=0.1, marker='s',
                   vmin=np.quantile(testing_data.T[sys_ind],0.01), vmax=np.quantile(testing_data.T[sys_ind], 0.99))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eae3423f4a8d> in <module>
#       2     #sys_ind = 1
#       3     hp.cartview(np.ones_like(weight_map)*hp.UNSEEN, lonra=[-31, 55], latra=[-37,-26], title='KiDS-South, '+columns_syst[sys_ind], flip='geo', cbar=None)
# ----> 4     hp.projscatter(radec.T[0], radec.T[1], lonlat=True, c=testing_data.T[sys_ind], cmap='coolwarm', s=0.1, marker='s',
#       5                    vmin=np.quantile(testing_data.T[sys_ind],0.01), vmax=np.quantile(testing_data.T[sys_ind], 0.99))
#
# NameError: name 'testing_data' is not defined

# %%
for sys_ind in range(train_data.shape[1]):
    hp.cartview(np.ones_like(weight_map)*hp.UNSEEN, lonra=[125-180, 240-180], latra=[-5,4], title='KiDS-North, '+columns_syst[sys_ind], flip='geo', cbar=None)
    hp.projscatter(radec.T[0]-180, radec.T[1], lonlat=True, c=train_data_raw.T[sys_ind], cmap='coolwarm', s=1, marker='.',
              vmin=np.quantile(train_data_raw.T[sys_ind],0.01), vmax=np.quantile(train_data_raw.T[sys_ind], 0.99))
